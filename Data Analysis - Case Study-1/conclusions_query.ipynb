# %% [markdown]
# # Drawing Conclusions Using Query

# %%
# Load 'winequality_edited.csv,' a file you created in a previous section 
import pandas as pd

df = pd.read_csv('winequality_edited.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color   acidity_levels
# 0      9.4        5   red              Low
# ...

# %% [markdown]
# ### Do wines with higher alcoholic content receive better ratings?

# %%
# get the median amount of alcohol content
df.median()
# Out:
# fixed_acidity            7.90000
# volatile_acidity         0.52000
# citric_acid              0.26000
# residual_sugar           2.20000
# chlorides                0.07900
# free_sulfur_dioxide     14.00000
# total_sulfur-dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
# select samples with alcohol content less than the median
low_alcohol = df.query('alcohol < 10.20')

# select samples with alcohol content greater than or equal to the median
high_alcohol = df.query('alcohol >= 10.20')

# ensure these queries included each sample exactly once
num_samples = df.shape[0]
num_samples == low_alcohol['quality'].count() + high_alcohol['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low alcohol and high alcohol groups
print('Mean Quality Rating for Low Alcohol: ',low_alcohol.mean().quality)
print('Mean Quality Rating for High Alcohol: ',high_alcohol.mean().quality)
# Out:
# Mean Quality Rating for Low Alcohol:  5.31030150754
# Mean Quality Rating for High Alcohol:  5.95890410959

# %% [markdown]
# ### Do sweeter wines receive better ratings?

# %%
# get the median amount of residual sugar
df.median()
# Out:
# fixed_acidity            7.90000
# volatile_acidity         0.52000
# citric_acid              0.26000
# residual_sugar           2.20000
# chlorides                0.07900
# free_sulfur_dioxide     14.00000
# total_sulfur-dioxide    38.00000
# density                  0.99675
# pH                       3.31000
# sulphates                0.62000
# alcohol                 10.20000
# quality                  6.00000
# dtype: float64

# %%
# select samples with residual sugar less than the median
low_sugar = df.query('residual_sugar < 2.20')

# select samples with residual sugar greater than or equal to the median
high_sugar = df.query('residual_sugar >= 2.20')

# ensure these queries included each sample exactly once
num_samples == low_sugar['quality'].count() + high_sugar['quality'].count() # should be True
# Out:
# True

# %%
# get mean quality rating for the low sugar and high sugar groups
print('Mean Quality Rating for Low Sugar: ',low_sugar.mean().quality)
print('Mean Quality Rating for High Sugar: ',high_sugar.mean().quality)
# Out:
# Mean Quality Rating for Low Sugar:  5.60239361702
# Mean Quality Rating for High Sugar:  5.66587957497

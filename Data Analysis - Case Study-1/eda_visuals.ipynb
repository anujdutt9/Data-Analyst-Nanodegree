# %% [markdown]
# # EDA with Visuals
# Create visualizations to answer the quiz questions below this notebook.

# %%
# Load dataset
import pandas as pd
import numpy as np

df = pd.read_csv('winequality_edited.csv')
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur-dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality color
# 0      9.4        5   red
# 1      9.8        5   red
# ...

# %% [markdown]
# ### Histograms for Various Features

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Histogram for FIxed Acidity
df['fixed_acidity'].plot(kind='hist');

# %%
# Histogram for Total Sulfur Dioxide
df['total_sulfur-dioxide'].plot(kind='hist');

# %%
# Histogram for Total Sulfur Dioxide
df['pH'].plot(kind='hist');

# %%
# Histogram for Total Sulfur Dioxide
df['alcohol'].plot(kind='hist');

# %% [markdown]
# ### Scatterplots of Quality Against Various Features

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur-dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'color'],
#       dtype='object')

# %%
# Quality vs Fixed Acidity
df.plot(x='quality', y='fixed_acidity', style='o')

# %%
# Quality vs Volatile Acidity
df.plot(x='volatile_acidity', y='quality', style='o');

# %%
# Quality vs Citric Acid
df.plot(x='quality', y='citric_acid', style='o');

# %%
# Quality vs Citric Acid
df.plot(x='citric_acid', y='quality', style='o');

# %%
# Quality vs Residual Sugar
df.plot(x='quality', y='residual_sugar', style='o');

# %%
# Quality vs Residual Sugar
df.plot(x='residual_sugar', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='chlorides', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='free_sulfur_dioxide', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='total_sulfur-dioxide', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='density', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='pH', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='sulphates', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='alcohol', y='quality', style='o');

# %%
# Quality vs Chlorides
df.plot(x='color', y='quality', style='o');

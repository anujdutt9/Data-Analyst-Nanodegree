# %%
# import pandas
import pandas as pd

# %%
# load cancer data into data frame
df = pd.read_csv('cancer_data.csv')
# display first five rows of data
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99           NaN          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3              NaN           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#            ...            radius_max  texture_max  perimeter_max  area_max  \
# 0          ...                 25.38          NaN         184.60    2019.0
# 1          ...                 24.99        23.41         158.80    1956.0
# 2          ...                 23.57        25.53         152.50    1709.0
# 3          ...                 14.91        26.50          98.87     567.7
# 4          ...                 22.54        16.67         152.20    1575.0
#
#    smoothness_max  compactness_max  concavity_max  concave_points_max  \
# 0          0.1622           0.6656         0.7119              0.2654
# 1          0.1238           0.1866         0.2416              0.1860
# 2          0.1444           0.4245         0.4504              0.2430
# 3             NaN           0.8663         0.6869              0.2575
# 4          0.1374           0.2050         0.4000              0.1625
#
#    symmetry_max  fractal_dimension_max
# 0        0.4601                0.11890
# 1        0.2750                0.08902
# 2        0.3613                0.08758
# 3        0.6638                0.17300
# 4        0.2364                0.07678
#
# [5 rows x 32 columns]

# %%
# print the column labels in the dataframe
for i, v in enumerate(df.columns):
    print(i, v)
# Out:
# 0 id
# 1 diagnosis
# 2 radius_mean
# 3 texture_mean
# 4 perimeter_mean
# 5 area_mean
# 6 smoothness_mean
# 7 compactness_mean
# 8 concavity_mean
# 9 concave_points_mean
# 10 symmetry_mean
# 11 fractal_dimension_mean
# 12 radius_SE
# 13 texture_SE
# 14 perimeter_SE
# 15 area_SE
# 16 smoothness_SE
# 17 compactness_SE
# 18 concavity_SE
# 19 concave_points_SE
# 20 symmetry_SE
# 21 fractal_dimension_SE
# 22 radius_max
# 23 texture_max
# 24 perimeter_max
# 25 area_max
# 26 smoothness_max
# 27 compactness_max
# 28 concavity_max
# 29 concave_points_max
# 30 symmetry_max
# 31 fractal_dimension_max

# %%
df.corr()
# Out:
#                               id  radius_mean  texture_mean  perimeter_mean  \
# id                      1.000000     0.075350      0.100756        0.073806
# radius_mean             0.075350     1.000000      0.333046        0.997859
# texture_mean            0.100756     0.333046      1.000000        0.338960
# perimeter_mean          0.073806     0.997859      0.338960        1.000000
# area_mean               0.097972     0.987269      0.328237        0.986285
# smoothness_mean        -0.011068     0.175538     -0.040782        0.212419
# compactness_mean       -0.001510     0.504040      0.248884        0.555001
# concavity_mean          0.050014     0.674439      0.312105        0.713784
# concave_points_mean     0.043858     0.821894      0.300493        0.850283
# symmetry_mean          -0.024164     0.154164      0.063187        0.189828
# fractal_dimension_mean -0.054187    -0.312620     -0.075106       -0.262577
# radius_SE               0.141720     0.680285      0.293019        0.693105
# texture_SE             -0.009847    -0.094712      0.388004       -0.085162
# perimeter_SE            0.136227     0.674242      0.299810        0.693321
# area_SE                 0.176976     0.736295      0.274004        0.745524
# smoothness_SE           0.108035    -0.197889     -0.011871       -0.178583
# compactness_SE          0.031640     0.198758      0.193899        0.243496
# concavity_SE            0.054396     0.188023      0.142963        0.221713
# concave_points_SE       0.077648     0.369993      0.156230        0.400928
# symmetry_SE            -0.024825    -0.110472      0.012294       -0.087717
# fractal_dimension_SE    0.023694    -0.047191      0.056061       -0.010216
# radius_max              0.081840     0.968065      0.366104        0.968295
# texture_max             0.064564     0.305228      0.912805        0.311328
# perimeter_max           0.079474     0.963457      0.373450        0.968950
# area_max                0.106366     0.938709      0.355693        0.939365
# smoothness_max          0.009829     0.121082      0.055032        0.152169
# compactness_max        -0.004538     0.412875      0.292090        0.455464
# concavity_max           0.022621     0.523596      0.311845        0.560598
# concave_points_max      0.034633     0.742126      0.304024        0.769221
# symmetry_max           -0.043408     0.164202      0.098194        0.191069
# fractal_dimension_max  -0.031620     0.010554      0.129833        0.054558
#
#                         area_mean  smoothness_mean  compactness_mean  \
# id                       0.097972        -0.011068         -0.001510
# radius_mean              0.987269         0.175538          0.504040
# texture_mean             0.328237        -0.040782          0.248884
# perimeter_mean           0.986285         0.212419          0.555001
# area_mean                1.000000         0.178994          0.495424
# smoothness_mean          0.178994         1.000000          0.656587
# compactness_mean         0.495424         0.656587          1.000000
# concavity_mean           0.682567         0.523786          0.883265
# concave_points_mean      0.821967         0.557107          0.830120
# symmetry_mean            0.157765         0.555623          0.604754
# fractal_dimension_mean  -0.284544         0.571654          0.565073
# radius_SE                0.735230         0.293924          0.495256
# texture_SE              -0.065475         0.042108          0.037012
# perimeter_SE             0.727918         0.292735          0.546094
# area_SE                  0.801807         0.242557          0.453333
# smoothness_SE           -0.144284         0.318094          0.138469
# compactness_SE           0.204656         0.310997          0.734162
# concavity_SE             0.200301         0.256300          0.566335
# concave_points_SE        0.365179         0.377626          0.638081
# symmetry_SE             -0.076154         0.178766          0.223234
# fractal_dimension_SE    -0.024704         0.260710          0.503168
# radius_max               0.961780         0.216897          0.534916
# texture_max              0.294411         0.030197          0.257571
# perimeter_max            0.957767         0.245210          0.589439
# area_max                 0.957390         0.208176          0.508012
# smoothness_max           0.123362         0.799669          0.560065
# compactness_max          0.389330         0.465383          0.866448
# concavity_max            0.508116         0.440146          0.816015
# concave_points_max       0.719254         0.502104          0.815087
# symmetry_max             0.141837         0.399238          0.533566
# fractal_dimension_max    0.006622         0.481355          0.689214
#
#                         concavity_mean  concave_points_mean  symmetry_mean  \
# id                            0.050014             0.043858      -0.024164
# radius_mean                   0.674439             0.821894       0.154164
# texture_mean                  0.312105             0.300493       0.063187
# perimeter_mean                0.713784             0.850283       0.189828
# area_mean                     0.682567             0.821967       0.157765
# smoothness_mean               0.523786             0.557107       0.555623
# compactness_mean              0.883265             0.830120       0.604754
# concavity_mean                1.000000             0.920327       0.508095
# concave_points_mean           0.920327             1.000000       0.469329
# symmetry_mean                 0.508095             0.469329       1.000000
# fractal_dimension_mean        0.337969             0.166561       0.474800
# radius_SE                     0.633529             0.698773       0.319302
# texture_SE                    0.069066             0.012151       0.113253
# perimeter_SE                  0.660723             0.709949       0.323511
# area_SE                       0.617817             0.690368       0.235104
# smoothness_SE                 0.107528             0.038597       0.145962
# compactness_SE                0.665388             0.482451       0.428949
# concavity_SE                  0.687234             0.431610       0.339039
# concave_points_SE             0.678030             0.608251       0.391707
# symmetry_SE                   0.172110             0.089924       0.452812
# fractal_dimension_SE          0.446572             0.252556       0.347879
# radius_max                    0.688196             0.831311       0.198118
# texture_max                   0.309294             0.300092       0.083834
# perimeter_max                 0.728972             0.856439       0.230324
# area_max                      0.674500             0.809377       0.190788
# smoothness_max                0.448545             0.455507       0.429608
# compactness_max               0.757313             0.669175       0.476025
# concavity_max                 0.883325             0.750679       0.438219
# concave_points_max            0.860399             0.909763       0.440103
# symmetry_max                  0.424790             0.392195       0.711924
# fractal_dimension_max         0.519262             0.373401       0.435295
#
#                                 ...            radius_max  texture_max  \
# id                              ...              0.081840     0.064564
# radius_mean                     ...              0.968065     0.305228
# texture_mean                    ...              0.366104     0.912805
# perimeter_mean                  ...              0.968295     0.311328
# area_mean                       ...              0.961780     0.294411
# smoothness_mean                 ...              0.216897     0.030197
# compactness_mean                ...              0.534916     0.257571
# concavity_mean                  ...              0.688196     0.309294
# concave_points_mean             ...              0.831311     0.300092
# symmetry_mean                   ...              0.198118     0.083834
# fractal_dimension_mean          ...             -0.251145    -0.051415
# radius_SE                       ...              0.715830     0.210550
# texture_SE                      ...             -0.110592     0.407230
# perimeter_SE                    ...              0.696834     0.216274
# area_SE                         ...              0.757511     0.209138
# smoothness_SE                   ...             -0.211839    -0.081453
# compactness_SE                  ...              0.196560     0.143834
# concavity_SE                    ...              0.180748     0.099482
# concave_points_SE               ...              0.350600     0.080432
# symmetry_SE                     ...             -0.131976    -0.070903
# fractal_dimension_SE            ...             -0.041524    -0.002759
# radius_max                      ...              1.000000     0.372507
# texture_max                     ...              0.372507     1.000000
# perimeter_max                   ...              0.993769     0.379336
# area_max                        ...              0.984036     0.357689
# smoothness_max                  ...              0.221501     0.222358
# compactness_max                 ...              0.476423     0.373154
# concavity_max                   ...              0.573470     0.379158
# concave_points_max              ...              0.787596     0.369333
# symmetry_max                    ...              0.252242     0.234092
# fractal_dimension_max           ...              0.100533     0.227944
#
#                         perimeter_max  area_max  smoothness_max  \
# id                           0.079474  0.106366        0.009829
# radius_mean                  0.963457  0.938709        0.121082
# texture_mean                 0.373450  0.355693        0.055032
# perimeter_mean               0.968950  0.939365        0.152169
# area_mean                    0.957767  0.957390        0.123362
# smoothness_mean              0.245210  0.208176        0.799669
# compactness_mean             0.589439  0.508012        0.560065
# concavity_mean               0.728972  0.674500        0.448545
# concave_points_mean          0.856439  0.809377        0.455507
# symmetry_mean                0.230324  0.190788        0.429608
# fractal_dimension_mean      -0.203136 -0.229634        0.495583
# radius_SE                    0.720728  0.752523        0.130176
# texture_SE                  -0.101781 -0.083492       -0.099135
# perimeter_SE                 0.720864  0.730392        0.123640
# area_SE                      0.761540  0.811472        0.118188
# smoothness_SE               -0.198236 -0.167057        0.303813
# compactness_SE               0.252207  0.190487        0.213241
# concavity_SE                 0.220174  0.181033        0.167672
# concave_points_SE            0.387405  0.333563        0.210736
# symmetry_SE                 -0.106412 -0.112191       -0.050110
# fractal_dimension_SE        -0.005469 -0.027253        0.146025
# radius_max                   0.993769  0.984036        0.221501
# texture_max                  0.379336  0.357689        0.222358
# perimeter_max                1.000000  0.977558        0.245126
# area_max                     0.977558  1.000000        0.214067
# smoothness_max               0.245126  0.214067        1.000000
# compactness_max              0.529546  0.438305        0.563797
# concavity_max                0.617266  0.541793        0.527343
# concave_points_max           0.816152  0.746796        0.550817
# symmetry_max                 0.276884  0.217748        0.498653
# fractal_dimension_max        0.145250  0.086189        0.603171
#
#                         compactness_max  concavity_max  concave_points_max  \
# id                            -0.004538       0.022621            0.034633
# radius_mean                    0.412875       0.523596            0.742126
# texture_mean                   0.292090       0.311845            0.304024
# perimeter_mean                 0.455464       0.560598            0.769221
# area_mean                      0.389330       0.508116            0.719254
# smoothness_mean                0.465383       0.440146            0.502104
# compactness_mean               0.866448       0.816015            0.815087
# concavity_mean                 0.757313       0.883325            0.860399
# concave_points_mean            0.669175       0.750679            0.909763
# symmetry_mean                  0.476025       0.438219            0.440103
# fractal_dimension_mean         0.458896       0.347263            0.176287
# radius_SE                      0.284745       0.379030            0.529212
# texture_SE                    -0.097724      -0.075812           -0.131111
# perimeter_SE                   0.338744       0.416217            0.551845
# area_SE                        0.281453       0.383258            0.536400
# smoothness_SE                 -0.059608      -0.062233           -0.100507
# compactness_SE                 0.673499       0.633031            0.475184
# concavity_SE                   0.481223       0.657731            0.434010
# concave_points_SE              0.449346       0.543641            0.595512
# symmetry_SE                    0.058548       0.033728           -0.031683
# fractal_dimension_SE           0.386149       0.375866            0.210226
# radius_max                     0.476423       0.573470            0.787596
# texture_max                    0.373154       0.379158            0.369333
# perimeter_max                  0.529546       0.617266            0.816152
# area_max                       0.438305       0.541793            0.746796
# smoothness_max                 0.563797       0.527343            0.550817
# compactness_max                1.000000       0.893891            0.802756
# concavity_max                  0.893891       1.000000            0.855108
# concave_points_max             0.802756       0.855108            1.000000
# symmetry_max                   0.629461       0.540744            0.517200
# fractal_dimension_max          0.813144       0.690915            0.517072
#
#                         symmetry_max  fractal_dimension_max
# id                         -0.043408              -0.031620
# radius_mean                 0.164202               0.010554
# texture_mean                0.098194               0.129833
# perimeter_mean              0.191069               0.054558
# area_mean                   0.141837               0.006622
# smoothness_mean             0.399238               0.481355
# compactness_mean            0.533566               0.689214
# concavity_mean              0.424790               0.519262
# concave_points_mean         0.392195               0.373401
# symmetry_mean               0.711924               0.435295
# fractal_dimension_mean      0.359925               0.764732
# radius_SE                   0.107841               0.051501
# texture_SE                 -0.128018              -0.053977
# perimeter_SE                0.119660               0.086282
# area_SE                     0.082372               0.019884
# smoothness_SE              -0.135929               0.092907
# compactness_SE              0.302391               0.586936
# concavity_SE                0.204577               0.435593
# concave_points_SE           0.154537               0.308075
# symmetry_SE                 0.398852               0.067853
# fractal_dimension_SE        0.135749               0.586710
# radius_max                  0.252242               0.100533
# texture_max                 0.234092               0.227944
# perimeter_max               0.276884               0.145250
# area_max                    0.217748               0.086189
# smoothness_max              0.498653               0.603171
# compactness_max             0.629461               0.813144
# concavity_max               0.540744               0.690915
# concave_points_max          0.517200               0.517072
# symmetry_max                1.000000               0.553180
# fractal_dimension_max       0.553180               1.000000
#
# [31 rows x 31 columns]
